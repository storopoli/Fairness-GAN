# %%
import pickle
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
with open('accuracy_cla.pickle', 'rb') as handle:
    accuracy_cla = pickle.load(handle)

# %%
with open('accuracy_dis.pickle', 'rb') as handle:
    accuracy_dis = pickle.load(handle)

# %%
accuracy_cla
# Out:
# [(0.0, 0.47044334975369456),
#  (0.01, 0.12523683213338385),
#  (0.02, 0.08980674497915878),
#  (0.03, 0.07730200833649109),
#  (0.04, 0.07104964001515726),
#  (0.05, 0.06271314892004547),
#  (0.06, 0.06043956043956044),
#  (0.07, 0.05930276619931792),
#  (0.08, 0.05627131489200455),
#  (0.09, 0.055323986358469114),
#  (0.1, 0.05096627510420614),
#  (0.11, 0.05096627510420614),
#  (0.12, 0.050776809397499054),
#  (0.13, 0.04964001515725654),
#  (0.14, 0.04907161803713528),
#  (0.15, 0.04869268662372111),
#  (0.16, 0.045471769609700646),
#  (0.17, 0.042629784009094354),
#  (0.18, 0.042629784009094354),
#  (0.19, 0.042061386888973096),
#  (0.2, 0.042061386888973096),
#  (0.21, 0.042061386888973096),
#  (0.22, 0.04149298976885184),
#  (0.23, 0.03751420992800303),
#  (0.24, 0.03751420992800303),
#  (0.25, 0.03694581280788178),
#  (0.26, 0.0365668813944676),
#  (0.27, 0.03637741568776052),
#  (0.28, 0.03467222432739674),
#  (0.29, 0.034293292913982566),
#  (0.3, 0.034103827207275485),
# ...

# %%
plt.plot(matches_cla)
plt.show()

# %%
plt.plot(matches_dis)
plt.show()
